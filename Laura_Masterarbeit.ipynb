# %% [markdown]
# <a href="https://colab.research.google.com/github/brunryan/BINA-FS24-WORK/blob/main/Laura_Masterarbeit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kollerationsmatrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

csv_korrelation = "https://raw.githubusercontent.com/brunryan/masterarbeit_laura/main/Daten_roh.csv"

# Schritt 1: CSV-Datei einlesen
df = pd.read_csv(csv_korrelation, sep=';', decimal=',')

df.describe().T
# Out:
#                                      count      mean       std  min  25%  50%  \
# Reputation AG                        365.0  5.326027  1.317885  1.0  5.0  5.0
# Image Ges                            365.0  5.068493  1.333515  1.0  4.0  5.0
# Lernplätze-Gruppenräume              365.0  4.342466  1.765194  1.0  3.0  5.0
# Mensa_Cafeteria                      365.0  3.816438  1.743671  1.0  2.0  4.0
# Modernen_Gebäude                     365.0  4.950685  1.543430  1.0  4.0  5.0
# Technische_Austatt                   365.0  5.397260  1.405833  1.0  5.0  6.0
# Begegnungsräume                      365.0  4.169863  1.686622  1.0  3.0  4.0
# Modul_Wahlmöglichkeiten              365.0  5.791781  1.136526  1.0  5.0  6.0
# Spezialisierungsmöglichkeiten        365.0  6.049315  1.039220  2.0  6.0  6.0
# Hochschul_Lern_Lehrklima?            365.0  5.010959  1.378760  1.0  4.0  5.0
# Interaktion_Dozierenden              365.0  5.005479  1.454426  1.0  4.0  5.0
# inter_didaktisch_Unterricht          365.0  5.736986  1.172898  1.0  5.0  6.0
# Lernerfolg                           365.0  5.876712  1.015609  2.0  5.0  6.0
# Wissen_anwenden                      365.0  6.043836  0.968315  2.0  5.0  6.0
# Unterrichtsmodule_Englisch           365.0  4.339726  1.854512  1.0  3.0  4.0
# Austauschsemester                    365.0  4.443836  1.838312  1.0  3.0  5.0
# Double_Degree                        365.0  3.224658  1.522341  1.0  2.0  3.0
# Incoming_Students_Kontakt            365.0  3.397260  1.582352  1.0  2.0  4.0
# Internat_Exkursionen                 365.0  4.197260  1.783469  1.0  3.0  4.0
# Standort_Allg                        365.0  6.238356  1.094772  1.0  6.0  7.0
# Nähe_Wohnort                         365.0  5.830137  1.360216  1.0  5.0  6.0
# Social Media                         365.0  3.167123  1.505307  1.0  2.0  3.0
# Werbung                              365.0  3.019178  1.426655  1.0  2.0  3.0
# Anwesenheit_Freunde                  365.0  3.983562  1.794299  1.0  2.0  4.0
# Empfehlung_Freunde_Family            365.0  5.000000  1.497250  1.0  4.0  5.0
# Empfehlung_Beruf                     365.0  4.619178  1.563725  1.0  4.0  5.0
# Empfehlung_Studierenden_Absolventen  365.0  4.980822  1.496209  1.0  4.0  5.0
#
#                                      75%  max
# Reputation AG                        6.0  7.0
# Image Ges                            6.0  7.0
# Lernplätze-Gruppenräume              6.0  7.0
# Mensa_Cafeteria                      5.0  7.0
# Modernen_Gebäude                     6.0  7.0
# Technische_Austatt                   6.0  7.0
# Begegnungsräume                      5.0  7.0
# Modul_Wahlmöglichkeiten              7.0  7.0
# Spezialisierungsmöglichkeiten        7.0  7.0
# Hochschul_Lern_Lehrklima?            6.0  7.0
# Interaktion_Dozierenden              6.0  7.0
# inter_didaktisch_Unterricht          7.0  7.0
# Lernerfolg                           7.0  7.0
# Wissen_anwenden                      7.0  7.0
# Unterrichtsmodule_Englisch           6.0  7.0
# Austauschsemester                    6.0  7.0
# Double_Degree                        4.0  7.0
# Incoming_Students_Kontakt            4.0  7.0
# Internat_Exkursionen                 6.0  7.0
# Standort_Allg                        7.0  7.0
# Nähe_Wohnort                         7.0  7.0
# Social Media                         4.0  7.0
# Werbung                              4.0  7.0
# Anwesenheit_Freunde                  5.0  7.0
# Empfehlung_Freunde_Family            6.0  7.0
# Empfehlung_Beruf                     6.0  7.0
# Empfehlung_Studierenden_Absolventen  6.0  7.0

# %%
# Überprüfen der Daten
print(df.head())

# Berechnen der Korrelationsmatrix
corr_matrix = df.corr()

# Korrelogramm erstellen
plt.figure(figsize=(14, 12))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8}, annot_kws={"size": 8})
plt.title('Korrelogramm der Variablen')
plt.show()
# Out:
#    Reputation AG  Image Ges  Lernplätze-Gruppenräume  Mensa_Cafeteria  \
# 0              5          4                        5                4
# 1              4          6                        6                3
# 2              4          4                        4                4
# 3              6          6                        4                4
# 4              5          5                        4                4
#
#    Modernen_Gebäude  Technische_Austatt  Begegnungsräume  \
# 0                 5                   5                5
# 1                 6                   4                6
# 2                 5                   5                4
# 3                 5                   6                6
# 4                 4                   4                4
#
#    Modul_Wahlmöglichkeiten   Spezialisierungsmöglichkeiten   \
# 0                         6                               6
# 1                         7                               6
# 2                         5                               7
# 3                         6                               6
# 4                         4                               6
#
#    Hochschul_Lern_Lehrklima?  ...  Incoming_Students_Kontakt  \
# 0                          6  ...                          7
# 1                          4  ...                          3
# 2                          5  ...                          7
# 3                          6  ...                          5
# 4                          4  ...                          1
#
#    Internat_Exkursionen  Standort_Allg  Nähe_Wohnort  Social Media  Werbung   \
# 0                     4              7             7             5         6
# 1                     5              7             7             3         4
# 2                     7              7             7             4         1
# 3                     4              5             4             4         4
# 4                     1              7             7             1         1
#
#    Anwesenheit_Freunde  Empfehlung_Freunde_Family  Empfehlung_Beruf  \
# 0                    4                          5                 5
# 1                    3                          5                 3
# 2                    4                          4                 4
# 3                    3                          5                 5
# 4                    1                          1                 2
#
#    Empfehlung_Studierenden_Absolventen
# 0                                    5
# 1                                    5
# 2                                    4
# 3                                    5
# 4                                    1
#
# [5 rows x 27 columns]

# %%
# Berechnen der Korrelationsmatrix
corr_matrix = df.corr()

# Maske für die obere Dreiecksmatrix erstellen
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Korrelogramm erstellen
plt.figure(figsize=(14, 12))
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8}, annot_kws={"size": 8})
plt.title('Korrelogramm der Variablen')
plt.show()
